# %%
import pandas
import numpy

import matplotlib.pyplot as plt

# %%
import scipy.spatial.distance
import scipy
import scipy.stats

# %%
fl = "/Users/simondi/PROJECTS/target_infect_x_project/src/tix-analysis/data/factor_analysis-sample/part-00000-a890c03a-24f7-4c45-8fdf-198e480c65df-c000.csv"

# %%
tab = pandas.read_csv(fl, sep="\t")
tab["Outlier"] = True

# %%
tab
# Out:
#                study  pathogen library design  replicate      plate well  \
# 0  infectx_published  listeria       a      u          1  kb2-02-1x  a01
# 1  infectx_published  listeria       a      u          1  kb2-02-1x  a01
# 2  infectx_published  listeria       a      u          1  kb2-02-1x  a01
# 3  infectx_published  listeria       a      u          1  kb2-02-1x  a02
# 4  infectx_published  listeria       a      u          1  kb2-02-1x  a03
# 5  infectx_published  listeria       a      u          1  kb2-02-1x  a05
# 6  infectx_published  listeria       a      u          1  kb2-02-1x  a06
# 7  infectx_published  listeria       a      u          1  kb2-02-1x  a06
# 8  infectx_published  listeria       a      u          1  kb2-02-1x  a09
#
#     gene    sirna well_type   ...          f_6       f_7       f_8       f_9  \
# 0   chka    s3008     sirna   ...    -0.056240  0.885446  0.009457 -0.491389
# 1   chka    s3008     sirna   ...    -0.041819  1.152283 -0.466570 -0.556871
# ...

# %%
stat = scipy.stats.chisquare(maha, )

# %%
stat.pvalue =
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
plt.style.use(["seaborn-whitegrid"])
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Tahoma']


_, ax = plt.subplots(figsize=(7, 4), dpi=720)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(True)
ax.spines["left"].set_visible(True)
ax.spines['left'].set_bounds(-2, 2)
ax.spines['bottom'].set_bounds(-2, 2)
ax.xaxis.set_label_coords(x=.95, y=-0.1)
ax.yaxis.set_label_coords(x=-0.05, y=.885)
ax.grid(linestyle="")
#ax.grid(which="major", axis="x", linestyle="-", color="gainsboro")
#ax.grid(which="major", axis="y", linestyle="-", color="gainsboro")
plt.scatter(tab["f_0"].values, tab["f_1"].values, color="black", alpha=.5)

plt.xlabel('Factor 1', fontsize=15)
plt.ylabel("Factor 2", fontsize=15)
plt.show()

# %%
plt.style.use(["seaborn-whitegrid"])
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Tahoma']


_, ax = plt.subplots(figsize=(7, 4), dpi=720)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(True)
ax.spines["left"].set_visible(True)
ax.xaxis.set_label_coords(x=.95, y=-0.1)
ax.yaxis.set_label_coords(x=-0.075, y=.885)

ax.grid(linestyle="")
plt.hist(tab["f_0"].values, color="black", alpha=.5, bins=50)

plt.xlabel('X', fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()
