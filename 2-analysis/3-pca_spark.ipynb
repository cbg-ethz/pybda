# %%
import os
import sys
import pandas
import numpy

import findspark
findspark.init("/usr/local/spark/spark")

import pyspark

from pyspark.ml.feature import PCA
from pyspark.ml.linalg import Vector, Vectors
from pyspark.ml.feature import StandardScaler
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
file_name = "/Users/simondi/Desktop/test_ba/kmeans_transform-cells_sample_10_normalized_cut_100_K005"

# %%
conf = pyspark.SparkConf().setMaster("local[*]").set("spark.driver.memory", "4G").set("spark.executor.memory", "4G")
sc = pyspark.SparkContext(conf=conf)
spark = pyspark.sql.SparkSession(sc)

# %%
data = spark.read.parquet(file_name)

# %%
data = data.limit(30)

# %%
data.take(1)
# Out:
# [Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='4', object_idx='144', prediction=0, features=DenseVector([-0.8044, 0.0121, 1.1159, 1.4749, -0.9369, -0.7485, -1.0209, -0.703, 0.0, 0.4476, 1.2809, 1.3916, 0.1489, 0.6694, -1.2335, -0.0825, 0.0106, -0.5078, 1.2455, 0.1357]))]

# %%
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures", withStd=True, withMean=True)
scalerModel = scaler.fit(data)
data = scalerModel.transform(data)

# %%
pca = PCA(k=2, inputCol="scaledFeatures", outputCol="pcs")

# %%
model = pca.fit(data)

# %%
data = model.transform(data)

# %%
model.explainedVariance
# Out:
# DenseVector([0.263, 0.2029])

# %%
counts = data.groupBy(["pathogen", "gene", "sirna"]).count()

# %%
window = Window.partitionBy(["pathogen", "gene", "sirna"]).rowsBetween(0, 10)

# %%
data = data.withColumn(
    "row_num",
    row_number().over(Window.partitionBy(["pathogen", "gene"]).orderBy(["pathogen", "gene"])))

# %%
data.select(["pathogen", "gene", "row_num"]).take(5)
# Out:
# [Row(pathogen='listeria', gene='chka', row_num=1),
#  Row(pathogen='listeria', gene='chka', row_num=2),
#  Row(pathogen='listeria', gene='chka', row_num=3),
#  Row(pathogen='listeria', gene='chka', row_num=4),
#  Row(pathogen='listeria', gene='chka', row_num=5)]

# %%
data = data.filter("row_num <= 10")

# %%
genes  = [i.gene for i in data.select("gene").distinct().sample(False, fraction=.5).limit(100).collect()]

# %%
genes
# Out:
# ['chka', 'grk5']

# %%
data.where(data.gene.isin(genes)).take(5)
# Out:
# [Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='4', object_idx='144', prediction=0, features=DenseVector([-0.8044, 0.0121, 1.1159, 1.4749, -0.9369, -0.7485, -1.0209, -0.703, 0.0, 0.4476, 1.2809, 1.3916, 0.1489, 0.6694, -1.2335, -0.0825, 0.0106, -0.5078, 1.2455, 0.1357]), scaledFeatures=DenseVector([-0.7828, 0.1618, 1.1262, 1.6892, -0.9413, -0.6545, -1.0412, -0.885, 0.0, 0.4695, 1.3531, 1.2438, 0.1884, 1.1718, -1.3546, -0.1607, -0.004, -0.7102, 1.6329, 0.1423]), pcs=DenseVector([2.1838, 1.6822]), row_num=1),
#  Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='5', object_idx='168', prediction=0, features=DenseVector([-0.9474, -0.0399, 0.1262, 0.6198, -1.0081, -0.7959, -0.9485, -0.6324, 0.0, 0.4263, -0.2104, -0.3939, 0.3941, -0.3786, 1.0053, -0.6748, 0.268, -1.0621, -0.5899, 0.429]), scaledFeatures=DenseVector([-0.9365, 0.1172, 0.0718, 0.607, -1.028, -0.6956, -0.9501, -0.7762, 0.0, 0.4488, -0.0603, -0.9836, 0.4309, -0.0569, 1.1044, -0.7633, 0.2468, -1.2904, -0.6414, 0.4391]), pcs=DenseVector([1.8602, 0.266]), row_num=2),
#  Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='2', object_idx='210', prediction=2, features=DenseVector([-0.0839, 1.1239, 1.7611, 0.8489, 0.5572, -0.7291, -0.4751, 0.4974, 0.0, 0.8014, -1.1155, 0.6997, 0.9706, -0.1785, 1.0668, 1.6943, 1.1014, 0.6542, -0.6529, 0.9422]), scaledFeatures=DenseVector([-0.0083, 1.1142, 1.8136, 0.8969, 0.876, -0.6377, -0.3544, 0.9648, 0.0, 0.8129, -0.9181, 0.3807, 1.0009, 0.1776, 1.172, 1.6471, 1.0587, 0.5061, -0.7196, 0.9586]), pcs=DenseVector([1.2484, -1.7653]), row_num=3),
#  Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='6', object_idx='207', prediction=4, features=DenseVector([-0.3139, 0.7065, -0.0913, 0.843, -0.1054, -0.559, -0.5982, -0.0675, 0.0, 0.8441, 0.1633, 0.5388, 0.897, -0.2843, -1.2915, 0.5098, 0.9911, 1.0606, 0.7454, 0.9056]), scaledFeatures=DenseVector([-0.2556, 0.7566, -0.16, 0.8895, 0.07, -0.4901, -0.5093, 0.0943, 0.0, 0.8543, 0.2939, 0.1799, 0.9281, 0.0536, -1.4183, 0.4419, 0.9513, 0.9314, 1.0132, 0.9215]), pcs=DenseVector([1.7612, -0.3717]), row_num=4),
#  Row(study='infectx_published', pathogen='listeria', library='a', design='u', replicate='1', plate='kb2-02-1x', well='a01', gene='chka', sirna='s3008', well_type='sirna', image_idx='2', object_idx='243', prediction=2, features=DenseVector([-0.3299, -1.9916, 1.6817, 0.5631, -0.8296, 0.351, -0.5286, 0.2149, 0.0, 1.1669, -0.3471, 1.3786, 1.3262, -0.3182, 1.4663, 1.6943, 1.4691, 0.4237, -1.1827, 1.3455]), scaledFeatures=DenseVector([-0.2728, -1.5547, 1.729, 0.5352, -0.8108, 0.2989, -0.4218, 0.5295, 0.0, 1.1677, -0.1898, 1.2277, 1.3526, 0.0139, 1.6108, 1.6471, 1.417, 0.2648, -1.376, 1.3668]), pcs=DenseVector([1.9484, -2.9613]), row_num=5)]

# %%
datap = data.select(
      ["pathogen", "gene", "sirna", "prediction", "pcs", "scaledFeatures"]).toPandas()

# %%
new_col_names = ["Feature_{}".format(x) for x in range(len(datap.loc[0, "scaledFeatures"]))]

# %%
# Out:
# ['chka', 'chuk', 'grk5']

# %%
data_p = data.select(["pathogen", "gene", "sirna", "prediction", "scaledFeatures", "pcs"]).toPandas()
data_p[['pc1','pc2']] = pandas.DataFrame(data_p.pcs.values.tolist())
data_p[ new_col_names ] = pandas.DataFrame(data_p.scaledFeatures.values.tolist())

# %%
data_p
# Out:
#     pathogen  gene  sirna  prediction  \
# 0   listeria  chka  s3008           0
# 1   listeria  chka  s3008           0
# 2   listeria  chka  s3008           2
# 3   listeria  chka  s3008           4
# 4   listeria  chka  s3008           2
# 5   listeria  chka  s3008           4
# 6   listeria  chka  s3008           1
# 7   listeria  chka  s3008           4
# 8   listeria  chka  s3008           3
# 9   listeria  chka  s3008           4
# 10  listeria  chuk  s3077           3
# 11  listeria  chuk  s3077           2
# 12  listeria  chuk  s3077           3
# 13  listeria  chuk  s3077           3
# 14  listeria  chuk  s3077           2
# 15  listeria  chuk  s3077           2
# 16  listeria  chuk  s3077           3
# 17  listeria  chuk  s3077           4
# 18  listeria  chuk  s3077           3
# 19  listeria  chuk  s3077           0
# 20  listeria  grk5  s6088           1
# 21  listeria  grk5  s6088           4
# 22  listeria  grk5  s6088           4
# 23  listeria  grk5  s6088           1
# 24  listeria  grk5  s6088           2
# 25  listeria  grk5  s6088           2
# 26  listeria  grk5  s6088           0
# 27  listeria  grk5  s6088           3
# 28  listeria  grk5  s6088           3
# 29  listeria  grk5  s6088           0
#
#                                        scaledFeatures  \
# 0   [-0.782821944903, 0.161762490353, 1.1261790614...
# 1   [-0.936524096425, 0.117235546461, 0.0718197915...
# 2   [-0.00830048862969, 1.11416647686, 1.813571601...
# 3   [-0.255597805045, 0.756608747896, -0.159959519...
# 4   [-0.272771229796, -1.55467060958, 1.7289851216...
# 5   [0.299533150033, -0.711028249524, -0.309593293...
# 6   [2.65315101217, -1.90727663834, -0.90018094079...
# 7   [-1.16450131, 0.0120308320822, 0.711968717046,...
# 8   [0.08658268312, 1.2546556183, -1.39021119143, ...
# 9   [-1.26367783793, 0.511720058032, -1.1636993586...
# 10  [-0.269765880465, 0.61905170554, 0.37853961174...
# 11  [0.838349351598, -0.372926820835, -0.114492505...
# 12  [-0.289515318929, 0.529788432384, 0.1465794902...
# 13  [0.600068083177, 0.874031362891, 1.90629729782...
# 14  [1.27197832656, 0.513235726627, -0.63127518932...
# 15  [-0.193773475941, -0.822846022702, 2.571344663...
# 16  [0.390122965595, -0.621130485895, -0.626412480...
# 17  [-0.783251280522, 0.760654988322, -0.867900429...
# 18  [-1.13659449478, 1.28801229227, -1.30919024129...
# 19  [-0.721856287037, -1.02821225512, -0.628127441...
# 20  [1.22002871669, -1.44598675484, -1.03069981649...
# 21  [-0.653162588033, 1.0723376131, -0.54846394042...
# 22  [-0.839064910963, 0.150404653367, -0.153203093...
# 23  [1.95719797413, 0.550858231734, -0.04341476795...
# 24  [1.11140680514, 0.284685782338, -0.42420665864...
# 25  [0.388834958739, -2.3130484293, -0.54364574920...
# 26  [-0.82275015745, -1.57999462709, -0.6427587162...
# 27  [0.608654795553, 0.648330467346, 0.44047682626...
# 28  [0.582035987189, 0.572777185559, 0.29176285792...
# 25    1.476281    1.044476    0.079604   -1.016322    1.522107    0.154620
# 26   -0.676409   -0.763271    0.163189    0.285259   -0.998884    0.129881
# 27   -1.478807   -0.160689   -0.624893   -0.057925    1.649484   -0.637035
# 28   -1.281772    1.044476   -0.947290    0.935204   -0.929579   -1.069971
# 29    0.137166   -2.571017    0.151248    0.871016   -0.400767    0.080402
#
# [30 rows x 28 columns]

# %%
uniq_genes = list(set(data_p["gene"]))
uniq_pathogen = list(set(data_p["pathogen"]))
uniq_sirnas = list(set(data_p["sirna"]))
uniq_clusts = list(set(data_p["prediction"]))

# %%
uniq_clusts
# Out:
# [0, 1, 2, 3, 4]

# %%
colors = plt.cm.rainbow(numpy.linspace(0, 1, len(uniq_clusts)))
colors
# Out:
# array([[  5.00000000e-01,   0.00000000e+00,   1.00000000e+00,
#           1.00000000e+00],
#        [  1.96078431e-03,   7.09281308e-01,   9.23289106e-01,
#           1.00000000e+00],
#        [  5.03921569e-01,   9.99981027e-01,   7.04925547e-01,
#           1.00000000e+00],
#        [  1.00000000e+00,   7.00543038e-01,   3.78411050e-01,
#           1.00000000e+00],
#        [  1.00000000e+00,   1.22464680e-16,   6.12323400e-17,
#           1.00000000e+00]])

# %%
data_p.loc[:, "color"] = colors[data_p.prediction]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-7c29b9866f46> in <module>()
# ----> 1 data_p.loc[:, "color"] = colors[data_p.prediction]
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     339                         new_indexer = convert_from_missing_indexer_tuple(
#     340                             indexer, self.obj.axes)
# --> 341                         self._setitem_with_indexer(new_indexer, value)
#     342
#     343                         return self.obj
#
# ~/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     561                     value = np.array(value, dtype=object)
#     562                     if len(labels) != value.shape[1]:
# --> 563                         raise ValueError('Must have equal len keys and value '
#     564                                          'when setting with an ndarray')
#     565
#
# ValueError: Must have equal len keys and value when setting with an ndarray

# %%
data_p
# Out:
#     pathogen  gene  sirna  prediction                                 pcs  \
# 0   listeria  chka  s3008           0      [1.76487012551, 1.61088575943]
# 1   listeria  chka  s3008           0     [1.63468301131, 0.594261298524]
# 2   listeria  chka  s3008           2     [1.75772043796, -1.00642121456]
# 3   listeria  chka  s3008           4     [2.02350481383, 0.100451937143]
# 4   listeria  chka  s3008           2     [2.25783110217, -2.77525388643]
# 5   listeria  chka  s3008           4     [1.53234179511, -1.49438655759]
# 6   listeria  chka  s3008           1    [-3.37821265856, -4.81525978572]
# 7   listeria  chka  s3008           4     [2.81887922754, 0.382042590338]
# 8   listeria  chka  s3008           3      [-2.03657176404, 2.7128186201]
# 9   listeria  chka  s3008           4        [2.16869401353, 1.386068262]
# 10  listeria  chuk  s3077           3      [-1.7822381539, 3.38880111141]
# 11  listeria  chuk  s3077           2   [-0.307352406099, -1.75029186953]
# 12  listeria  chuk  s3077           3     [-1.54968833094, 1.77802544749]
# 13  listeria  chuk  s3077           3    [-1.52442407079, 0.943343910425]
# 14  listeria  chuk  s3077           2  [-0.0684067194932, -1.91648700458]
# 15  listeria  chuk  s3077           2     [3.1392067248, -0.644025011857]
# 16  listeria  chuk  s3077           3   [-2.17977073017, -0.400071954322]
# 17  listeria  chuk  s3077           4    [3.13936625309, -0.289717211593]
# 18  listeria  chuk  s3077           3     [-0.957483481107, 4.0613641157]
# 19  listeria  chuk  s3077           0     [-1.58068358009, 1.77614069068]
# 20  listeria  grk5  s6088           1   [-4.09214940708, -0.922741157153]
# 21  listeria  grk5  s6088           4     [2.40663332298, -1.16081368412]
# 22  listeria  grk5  s6088           4     [1.23731778698, 0.272323226064]
# 23  listeria  grk5  s6088           1   [-3.39519942575, -0.442999877945]
# 24  listeria  grk5  s6088           2    [0.0368767455798, -1.5310057482]
# 25  listeria  grk5  s6088           2   [-0.771860264064, -2.41131017641]
# 26  listeria  grk5  s6088           0  [0.921226231163, -0.0295039781433]
# 27  listeria  grk5  s6088           3     [-1.6844954313, 0.848858464726]
# 28  listeria  grk5  s6088           3    [-1.96041888318, 0.852247084483]
# 29  listeria  grk5  s6088           0         [2.78588642418, 3.04065281]
#
#          pc1       pc2
# 0   1.764870  1.610886
# 1   1.634683  0.594261
# 2   1.757720 -1.006421
# 3   2.023505  0.100452
# 4   2.257831 -2.775254
# 5   1.532342 -1.494387
# 6  -3.378213 -4.815260
# 7   2.818879  0.382043
# 8  -2.036572  2.712819
# 9   2.168694  1.386068
# 10 -1.782238  3.388801
# 11 -0.307352 -1.750292
# 12 -1.549688  1.778025
# 13 -1.524424  0.943344
# 14 -0.068407 -1.916487
# 15  3.139207 -0.644025
# 16 -2.179771 -0.400072
# 17  3.139366 -0.289717
# 18 -0.957483  4.061364
# 19 -1.580684  1.776141
# 20 -4.092149 -0.922741
# 21  2.406633 -1.160814
# 22  1.237318  0.272323
# 23 -3.395199 -0.443000
# 24  0.036877 -1.531006
# 25 -0.771860 -2.411310
# 26  0.921226 -0.029504
# 27 -1.684495  0.848858
# 28 -1.960419  0.852247
# 29  2.785886  3.040653

# %%
hot = plt.get_cmap('hot')
colors = plt.cm.rainbow(np.linspace(0, 1, len(uniq_clusts)))

plt.figure()

plt.scatter(data_p.loc[:, "pc1"], data_p.loc[:, "pc2"], color=colors)
    
#uid = str(uuid.uuid1())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-55deabb01667> in <module>()
#       1 hot = plt.get_cmap('hot')
# ----> 2 colors = plt.cm.rainbow(np.linspace(0, 1, len(uniq_clusts)))
#       3
#       4 plt.figure()
#       5
#
# NameError: name 'np' is not defined

# %%
font = {'weight': 'normal',
            'family': 'sans-serif',
            'size': 14}
plt.rc('font', **font)
plt.figure()
ax = plt.subplot(111)
plt.tick_params(axis="both", which="both", bottom="off", top="off",
                labelbottom="on", left="off", right="off", labelleft="on")
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(True)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(True)

# %%
data

# %%
ax.plot(ks, score, "black")
    ax.plot(ks, score, "or")
    plt.xlabel('K', fontsize=15)
    plt.ylabel(axis_label, fontsize=15)
    plt.title('')
    ax.grid(True)
    logger.info("Saving plot to: {}".format(plotfile))
    plt.savefig(plotfile, bbox_inches="tight")
