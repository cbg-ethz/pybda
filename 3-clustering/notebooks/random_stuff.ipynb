# %%
import pandas
import numpy

# %%
fl = "/Users/simondi/PROJECTS/target_infect_x_project/src/tix-analysis/data/kmeans-transformed-clusters/cluster-0.tsv"

# %%
fl2 = "/Users/simondi/PROJECTS/target_infect_x_project/src/tix-analysis/data/kmeans-fit-K2_sse.tsv"

# %%
d =  pandas.read_csv(fl2, sep="\t")

# %%
d
# Out:
#           SSE   N   P  K
# 0  822.099098  94  15  2

# %%
matr = pandas.read_csv(fl, sep="\t", nrows=1000, usecols=lambda x: x.startswith("f_"))

# %%
matr
# Out:
#          f_0       f_1       f_2       f_3       f_4       f_5       f_6  \
# 0  -1.003658  0.085274  0.197032 -0.964995  1.129380  1.042910 -0.171486
# 1   0.784961  1.559620 -0.146064  0.521765  1.545419 -0.700311  0.017749
# 2  -0.234562  2.220134  0.220290  0.584940  0.786403 -0.784821 -0.016866
# 3  -0.294212  0.956728  0.574683  1.709418  1.256480  0.821547  0.071829
# 4   0.185288  0.979411  0.152929  0.447373  0.568263 -1.179948  0.088387
# 5  -1.014659  1.325111  0.025889  0.700651  1.193322 -0.390503  0.012633
# 6  -0.085144  1.398571 -0.115649  0.535643  1.192458 -1.222086  0.034654
# 7  -0.404906  1.505735 -0.184642  0.697797  0.578283  0.275995 -0.108729
# 8  -1.868028  1.884044  0.273870  0.304406  0.900401  0.058493 -0.080385
# 9  -0.207894  1.862896 -0.773403 -0.067005  1.146480  1.081343 -0.032722
# 10 -0.461663  0.386885  0.505867  0.464756  0.568083 -0.609192  0.179086
# 11 -0.636856 -1.097917  0.771446 -1.166651 -0.724793  1.772356  0.155142
# ...

# %%
matr["f_0"]
# Out:
# 0    -1.003658
# 1     0.784961
# 2    -0.234562
# 3    -0.294212
# 4     0.185288
# 5    -1.014659
# 6    -0.085144
# 7    -0.404906
# 8    -1.868028
# 9    -0.207894
# 10   -0.461663
# 11   -0.636856
# 12   -1.453983
# Name: f_0, dtype: float64

# %%
matr["features"].split(",", expand=True).as_matrix().astype(numpy.float64)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a8952560268b> in <module>()
#       1
# ----> 2 matr["features"].split(",", expand=True).as_matrix().astype(numpy.float64)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'
